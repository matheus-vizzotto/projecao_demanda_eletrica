# %% [markdown]
# # LightGBM

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np
from load import load_data
from load import series_to_supervised
from load import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from load import get_measures
import lightgbm as lgb
from collections import defaultdict
import json
import warnings
warnings.filterwarnings("ignore")

rcParams['figure.figsize'] = 15, 5 # tamanho das figuras

# %%
def lightgbm_forecast(train, testX):
	# transform list into array
	train = np.asarray(train)
	# split into input and output columns
	trainX, trainy = train[:, :-1], train[:, -1]
	# fit model
	model = lgb.LGBMRegressor(objective='regression', n_estimators=1000)
	model.fit(trainX, trainy)
	# make a one-step prediction
	yhat = model.predict([testX])
	return yhat[0]

# walk-forward validation for univariate data
def walk_forward_validation(data, n_test):
    predictions = list()
    # split dataset
    train, test = train_test_split(data, n_test)
    # seed history with training dataset
    history = [x for x in train]
    # step over each time-step in the test set
    for i in range(len(test)):
        # split test row into input and output columns
        testX, testy = test[i, :-1], test[i, -1]
        # fit model on history and make a prediction
        yhat = lightgbm_forecast(history, testX)
        # store forecast in list of predictions
        predictions.append(yhat)
        # add actual observation to history for the next loop
        history.append(test[i])
        # summarize progress
        print('>expected = %.1f, predicted = %.1f' % (testy, yhat))
    # estimate prediction error
    mae = mean_absolute_error(test[:, -1], predictions)
    mape = mean_absolute_percentage_error(test[:, -1], predictions)
    rmse = np.sqrt(mean_squared_error(test[:, -1], predictions))    
    return mae, mape, rmse, test[:, -1], predictions

def multi_step_forecast(data, lag, n):
    n_test = outs = n
    #data = series_to_supervised(values, n_in = lag, n_out = outs, dropnan=False)
    train, test = train_test_split(data, n_test)
    train.dropna(inplace = True)
    response_vars = data.columns[-(outs):]
    predictions = list()
    for h, response in enumerate(response_vars):
        cols = [x for x in data.columns[:lag]]
        cols.append(response)
        data_ = train[cols]
        nrows = data_.shape[0]
        data_ = data_.iloc[:nrows-h, :] 
        data_X, data_y = data_.iloc[:, :-1], data_.iloc[:, -1]
        model = lgb.LGBMRegressor(objective='regression', n_estimators=1000)
        model.fit(data_X, data_y)
        testX, testy = test.reset_index(drop=True).loc[0, :"var1(t-1)"], test.reset_index(drop=True).loc[0, response]
        pred = model.predict([testX])[0]
        print(f"Predicting {response}\n  > expected: {testy}, predicted: {pred}")
        predictions.append(pred)
    measures = get_measures(pd.Series(predictions), test["var1(t)"])
    df_measures = pd.DataFrame([measures])
    return predictions, df_measures

# %%
df_load = load_data()
df_weather = pd.read_csv("../data/weather_daily_data.csv", parse_dates=["DATA"])
# gets the same period for both dataframes
df_weather = df_weather[df_weather.DATA.isin(df_load.index)]
df_load = df_load[df_weather.DATA.min():df_weather.DATA.max()] 

df_load_2 = df_load.reset_index()
df_merged = pd.merge(df_weather, df_load_2, left_on = "DATA", right_on = "date", how = "outer")
df_merged.drop("date", axis = 1, inplace = True)

df_merged.dropna(how = "all", inplace = True)
df_merged.sort_values(by = "DATA", inplace = True)
df_merged.load_mwmed = df_merged.load_mwmed.interpolate(method="linear")

# %%
lag = 15
outs = n_test = 15
df_load_3 = df_merged.load_mwmed
df_load_3.index = df_merged.DATA
df_load_3 = df_load_3["2008-01-01":]
values = df_load_3.values.tolist()
data1 = series_to_supervised(values, n_in = lag, n_out=outs, dropnan=False)
data2 = pd.DataFrame()
df_weather.set_index("DATA", inplace=True) # TESTE: MAPE PASSOU DE 3,2 PARA 3,0
df_weather = df_weather["2008-01-01":] 
for col in df_weather.columns:
    if col == "DATA":
        continue
    else:
        values = df_weather[col].values.tolist()
        df_ = series_to_supervised(values, n_in = lag, dropnan=False)
        df_.drop("var1(t)", axis = 1, inplace = True) # the response variable is the load dataframe
        df_.columns = [f"{x}_{col}" for x in df_.columns]
        data2 = pd.concat([data2, df_], axis = 1)
df_weather_load = pd.concat([data2, data1], axis = 1)
df_weather_load
# Out:
#       var1(t-15)_PRECIPITACAO_PR  var1(t-14)_PRECIPITACAO_PR  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# ...                          ...                         ...
# 5260                         5.2                         2.2
# 5261                         2.2                        73.2
# 5262                        73.2                        15.0
# 5263                        15.0                         1.6
# 5264                         1.6                         0.2
#
#       var1(t-13)_PRECIPITACAO_PR  var1(t-12)_PRECIPITACAO_PR  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# ...                          ...                         ...
# 5260                        73.2                        15.0
# 5261                        15.0                         1.6
# 5262                         1.6                         0.2
# 5263                         0.2                         0.2
# 5264                         0.2                         1.4
#
#       var1(t-11)_PRECIPITACAO_PR  var1(t-10)_PRECIPITACAO_PR  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# ...                          ...                         ...
# 5260                         1.6                         0.2
# 5261                         0.2                         0.2
# 5262                         0.2                         1.4
# 5263                         1.4                         0.4
# 5264                         0.4                         0.2
#
#       var1(t-9)_PRECIPITACAO_PR  var1(t-8)_PRECIPITACAO_PR  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 5260                        0.2                        1.4
# 5261                        1.4                        0.4
# 5262                        0.4                        0.2
# 5263                        0.2                        0.0
# 5264                        0.0                        0.0
#
#       var1(t-7)_PRECIPITACAO_PR  var1(t-6)_PRECIPITACAO_PR  ...    var1(t+5)  \
# 0                           NaN                        NaN  ...  6930.564167
# 1                           NaN                        NaN  ...  9086.430417
# 2                           NaN                        NaN  ...  9437.825000
# 3                           NaN                        NaN  ...  9535.760417
# 4                           NaN                        NaN  ...  9946.955417
# ...                         ...                        ...  ...          ...
# 5260                        0.4                        0.2  ...          NaN
# 5261                        0.2                        0.0  ...          NaN
# 5262                        0.0                        0.0  ...          NaN
# 5263                        0.0                        0.0  ...          NaN
# 5264                        0.0                        0.4  ...          NaN
#
#         var1(t+6)    var1(t+7)    var1(t+8)    var1(t+9)   var1(t+10)  \
# 0     9086.430417  9437.825000  9535.760417  9946.955417  9684.091667
# 1     9437.825000  9535.760417  9946.955417  9684.091667  8194.232083
# 2     9535.760417  9946.955417  9684.091667  8194.232083  6997.824167
# 3     9946.955417  9684.091667  8194.232083  6997.824167  9407.491250
# 4     9684.091667  8194.232083  6997.824167  9407.491250  9897.250000
# ...           ...          ...          ...          ...          ...
# 5260          NaN          NaN          NaN          NaN          NaN
# 5261          NaN          NaN          NaN          NaN          NaN
# 5262          NaN          NaN          NaN          NaN          NaN
# 5263          NaN          NaN          NaN          NaN          NaN
# 5264          NaN          NaN          NaN          NaN          NaN
#
#        var1(t+11)   var1(t+12)   var1(t+13)   var1(t+14)
# 0     8194.232083  6997.824167  9407.491250  9897.250000
# 1     6997.824167  9407.491250  9897.250000  9960.365417
# 2     9407.491250  9897.250000  9960.365417  9751.891667
# 3     9897.250000  9960.365417  9751.891667  9676.098333
# 4     9960.365417  9751.891667  9676.098333  8231.710417
# ...           ...          ...          ...          ...
# 5260          NaN          NaN          NaN          NaN
# 5261          NaN          NaN          NaN          NaN
# 5262          NaN          NaN          NaN          NaN
# 5263          NaN          NaN          NaN          NaN
# 5264          NaN          NaN          NaN          NaN
#
# [5265 rows x 300 columns]

# %%
# SEM FUNÇÃO
#n_test = outs = 10 # com 10 funciona, com outros horizontes não
train, test = train_test_split(df_weather_load, n_test)
train.dropna(inplace = True)
response_vars = df_weather_load.columns[-(outs):]
predictions = list()
for h, response in enumerate(response_vars):
    cols = [x for x in df_weather_load.columns[:df_weather_load.shape[1] - outs]]
    print(cols)
    cols.append(response)
    data_ = train[cols]
    nrows = data_.shape[0]
    data_ = data_.iloc[:nrows-h, :] 
    data_X, data_y = data_.iloc[:, :-1], data_.iloc[:, -1]
    model = lgb.LGBMRegressor(objective='regression', n_estimators=1000)
    model.fit(data_X, data_y)
    testX, testy = test.reset_index(drop=True).loc[0, :"var1(t-1)"], test.reset_index(drop=True).loc[0, response]
    pred = model.predict([testX])[0]
    print(f"Predicting {response}\n  > expected: {testy}, predicted: {pred}")
    predictions.append(pred)
measures = get_measures(pd.Series(predictions), test["var1(t)"])
df_measures = pd.DataFrame([measures])
print(df_measures)

# %%
def multi_step_forecast(data, n):
    n_test = outs = n
    train, test = train_test_split(data, n_test)
    train.dropna(inplace = True)
    response_vars = data.columns[-(outs):]
    predictions = list()
    for h, response in enumerate(response_vars):
        cols = [x for x in data.columns[:data.shape[1] - outs]]
        cols.append(response)
        data_ = train[cols]
        nrows = data_.shape[0]
        data_ = data_.iloc[:nrows-h, :] 
        data_X, data_y = data_.iloc[:, :-1], data_.iloc[:, -1]
        model = lgb.LGBMRegressor(objective='regression', n_estimators=1000)
        model.fit(data_X, data_y)
        #teste = train.loc[:, :"var1(t-1)"].iloc[-1,:] # t + 3 (observado = 12.054,20)
        testX, testy = test.reset_index(drop=True).loc[0, :"var1(t-1)"], test.reset_index(drop=True).loc[0, response]
        pred = model.predict([testX])[0]
        print(f"Predicting {response}\n  > expected: {testy}, predicted: {pred}")
        predictions.append(pred)
    measures = get_measures(pd.Series(predictions), test["var1(t)"])
    df_measures = pd.DataFrame([measures])
    #return predictions
    return df_measures

multi_step_forecast(df_weather_load, outs)

# %%
lag = 15
outs = n_test = horz = 15
df_load_3 = df_merged.load_mwmed
df_load_3.index = df_merged.DATA
df_load_3 = df_load_3["2008-01-01":]
values = df_load_3.values.tolist()
data1 = series_to_supervised(values, n_in = lag, n_out=outs, dropnan=False)
data2 = pd.DataFrame()
df_weather = df_weather["2008-01-01":] 
for col in df_weather.columns:
    if col == "DATA":
        continue
    else:
        values = df_weather[col].values.tolist()
        df_ = series_to_supervised(values, n_in = lag, dropnan=False)
        df_.drop("var1(t)", axis = 1, inplace = True) # the response variable is the load dataframe
        df_.columns = [f"{x}_{col}" for x in df_.columns]
        data2 = pd.concat([data2, df_], axis = 1)
df_weather_load = pd.concat([data2, data1], axis = 1)


folds = 15 #partições
rows = df_weather_load.shape[0]
out = defaultdict(dict)
for fold in range(folds,0,-1):
    slide = rows-((fold-1)*horz)
    df_cv = df_weather_load.iloc[:slide,:]
    #print(df_cv.tail())
    
    train, test = train_test_split(df_cv, n_test)
    train.dropna(inplace = True)
    response_vars = df_weather_load.columns[-(outs):]
    print(f"predicting for cv {fold}...")
    predictions = list()
    for h, response in enumerate(response_vars):
        cols = [x for x in df_cv.columns[:df_cv.shape[1] - outs]]
        cols.append(response)
        data_ = train[cols]
        nrows = data_.shape[0]
        data_ = data_.iloc[:nrows-h, :] 
        data_X, data_y = data_.iloc[:, :-1], data_.iloc[:, -1]
        model = lgb.LGBMRegressor(objective='regression', n_estimators=1000)
        model.fit(data_X, data_y)
        #print(data_X)
        testX, testy = test.reset_index(drop=True).loc[0, :"var1(t-1)"], test.reset_index(drop=True).loc[0, response]
        pred = model.predict([testX])[0]
        print(f"\tPredicting {response}\n\t\t> expected: {testy}, predicted: {pred}")
        predictions.append(pred)
    out[f"cv_{fold}"]["pred"] = predictions
    out[f"cv_{fold}"]["test"] = test["var1(t)"].to_list()
d = dict(out)
# Out:
# predicting for cv 15...
# 	Predicting var1(t)
# 		> expected: 11379.10191667, predicted: 11120.64195323591
# 	Predicting var1(t+1)
# 		> expected: 11366.35033333, predicted: 11434.137402912362
# 	Predicting var1(t+2)
# 		> expected: 11496.866375, predicted: 11537.263134749051
# 	Predicting var1(t+3)
# 		> expected: 12086.04983333, predicted: 11593.718153783759
# 	Predicting var1(t+4)
# 		> expected: 10735.20925, predicted: 9870.66685356207
# 	Predicting var1(t+5)
# 		> expected: 8756.46366667, predicted: 8251.274338480027
# 	Predicting var1(t+6)
# 		> expected: 11573.89458333, predicted: 11217.833489038281
# 	Predicting var1(t+7)
# 		> expected: 12407.179875, predicted: 11432.72106594176
# 	Predicting var1(t+8)
# 		> expected: 12829.40883333, predicted: 11842.393176522988
# 	Predicting var1(t+9)
# 		> expected: 13124.67345833, predicted: 11953.729351723652
# 	Predicting var1(t+10)
# 		> expected: 12997.84475, predicted: 12312.727579690607
# 	Predicting var1(t+11)
# 		> expected: 11222.38875, predicted: 10754.774500011777
# 	Predicting var1(t+12)
# 		> expected: 9698.73195833, predicted: 8778.857602514116
# 	Predicting var1(t+13)
# 		> expected: 11705.406875, predicted: 11126.300061277265
# 	Predicting var1(t+14)
# 		> expected: 10842.36954167, predicted: 11408.498107350893
# predicting for cv 14...
# 	Predicting var1(t)
# 		> expected: 13257.61425, predicted: 11640.906323748803
# 	Predicting var1(t+1)
# 		> expected: 13684.007625, predicted: 12372.628586825967
# 	Predicting var1(t+2)
# 		> expected: 13879.06420833, predicted: 12662.144469778541
# 	Predicting var1(t+3)
# 		> expected: 11842.47825, predicted: 11172.7356339524
# 	Predicting var1(t+4)
# 		> expected: 9886.60795833, predicted: 9457.760360276367
# 	Predicting var1(t+5)
# 		> expected: 12696.58891667, predicted: 11517.588066560163
# 	Predicting var1(t+6)
# 		> expected: 13121.16454167, predicted: 11127.715126251891
# 	Predicting var1(t+7)
# 		> expected: 13260.59975, predicted: 11541.367359636371
# 	Predicting var1(t+8)
# 		> expected: 13206.842875, predicted: 12229.53463773387
# 	Predicting var1(t+9)
# 		> expected: 13022.40420833, predicted: 11986.46188093536
# 	Predicting var1(t+10)
# 		> expected: 11088.472, predicted: 11545.726567136298
# 	Predicting var1(t+11)
# 		> expected: 9726.269875, predicted: 10231.449374250567
# 	Predicting var1(t+12)
# 		> expected: 11011.97858333, predicted: 12082.61933716202
# 	Predicting var1(t+13)
# 		> expected: 13698.325, predicted: 11857.428995282497
# 	Predicting var1(t+14)
# 		> expected: 13726.26883333, predicted: 12331.920751313366
# predicting for cv 13...
# 	Predicting var1(t)
# 		> expected: 13209.97541667, predicted: 13154.840222783647
# 	Predicting var1(t+1)
# 		> expected: 12806.82704167, predicted: 13103.001136509643
# 	Predicting var1(t+2)
# 		> expected: 10989.01258333, predicted: 11711.486235415558
# 	Predicting var1(t+3)
# 		> expected: 9797.85508333, predicted: 9895.741300749069
# 	Predicting var1(t+4)
# 		> expected: 13441.66175, predicted: 11439.472366619844
# 	Predicting var1(t+5)
# 		> expected: 13938.80545833, predicted: 12744.022906472102
# 	Predicting var1(t+6)
# 		> expected: 13736.500625, predicted: 13025.575076983054
# 	Predicting var1(t+7)
# 		> expected: 13830.02595833, predicted: 13101.286766649264
# 	Predicting var1(t+8)
# 		> expected: 13407.75958333, predicted: 12390.972995794367
# 	Predicting var1(t+9)
# 		> expected: 11639.943625, predicted: 11063.284852569905
# 	Predicting var1(t+10)
# 		> expected: 10502.13983333, predicted: 9159.063372349005
# 	Predicting var1(t+11)
# 		> expected: 13402.63854167, predicted: 11494.709067107618
# 	Predicting var1(t+12)
# 		> expected: 13696.05245833, predicted: 11904.536714639042
# 	Predicting var1(t+13)
# 		> expected: 13752.0245, predicted: 12465.007297881619
# 	Predicting var1(t+14)
# 		> expected: 13672.46875, predicted: 12799.949983648916
# predicting for cv 12...
# 	Predicting var1(t)
# 		> expected: 13473.23216667, predicted: 13887.120493410526
# 	Predicting var1(t+1)
# 		> expected: 11999.059125, predicted: 11732.050692498102
# 	Predicting var1(t+2)
# 		> expected: 10706.93045833, predicted: 10538.62444200686
# 	Predicting var1(t+3)
# 		> expected: 13229.765, predicted: 12959.279809159058
# 	Predicting var1(t+4)
# 		> expected: 13090.19925, predicted: 12436.075139715798
# 	Predicting var1(t+5)
# 		> expected: 12988.82679167, predicted: 12715.337819117338
# 	Predicting var1(t+6)
# 		> expected: 13223.10720833, predicted: 12737.883082795017
# 	Predicting var1(t+7)
# 		> expected: 13296.81658333, predicted: 12925.017593912493
# 	Predicting var1(t+8)
# 		> expected: 12080.35766667, predicted: 11149.934658105383
# 	Predicting var1(t+9)
# 		> expected: 11096.48516667, predicted: 10458.941969590927
# 	Predicting var1(t+10)
# 		> expected: 14582.30279167, predicted: 12400.70444873663
# 	Predicting var1(t+11)
# 		> expected: 14485.2685, predicted: 12949.167828658994
# 	Predicting var1(t+12)
# 		> expected: 14467.71883333, predicted: 12314.662144759908
# 	Predicting var1(t+13)
# 		> expected: 14724.23229167, predicted: 12481.644564674127
# 	Predicting var1(t+14)
# 		> expected: 14347.44079167, predicted: 12786.120153913853
# predicting for cv 11...
# 	Predicting var1(t)
# 		> expected: 12342.46933333, predicted: 13002.356161939595
# 	Predicting var1(t+1)
# 		> expected: 10764.92783333, predicted: 11156.793394838782
# 	Predicting var1(t+2)
# 		> expected: 13622.87158333, predicted: 13280.412647819343
# 	Predicting var1(t+3)
# 		> expected: 14010.29254167, predicted: 13112.05110857563
# 	Predicting var1(t+4)
# 		> expected: 13471.72716667, predicted: 12936.810146029111
# 	Predicting var1(t+5)
# 		> expected: 12526.303375, predicted: 13009.96307665536
# 	Predicting var1(t+6)
# 		> expected: 10605.64254167, predicted: 12681.749908502565
# 	Predicting var1(t+7)
# 		> expected: 9233.632125, predicted: 12481.668549889871
# 	Predicting var1(t+8)
# 		> expected: 10247.09033333, predicted: 10849.504995378764
# 	Predicting var1(t+9)
# 		> expected: 12344.74091667, predicted: 13078.340925848373
# 	Predicting var1(t+10)
# 		> expected: 12652.59966667, predicted: 12401.98143709052
# 	Predicting var1(t+11)
# 		> expected: 12591.65325, predicted: 12626.22579109704
# 	Predicting var1(t+12)
# 		> expected: 12254.52016667, predicted: 13416.301563457659
# 	Predicting var1(t+13)
# 		> expected: 10689.66916667, predicted: 13197.106101016961
# 	Predicting var1(t+14)
# 		> expected: 9892.03791667, predicted: 12598.079646754293
# predicting for cv 10...
# 	Predicting var1(t)
# 		> expected: 10932.61854167, predicted: 11023.270100693593
# 	Predicting var1(t+1)
# 		> expected: 13622.07341667, predicted: 12519.441473926796
# 	Predicting var1(t+2)
# 		> expected: 13947.35933333, predicted: 12579.639216989655
# 	Predicting var1(t+3)
# 		> expected: 13600.00045833, predicted: 11901.743100547497
# 	Predicting var1(t+4)
# 		> expected: 12916.30154167, predicted: 11992.15325879392
# 	Predicting var1(t+5)
# 		> expected: 12635.79425, predicted: 11082.613502596074
# 	Predicting var1(t+6)
# 		> expected: 11234.50275, predicted: 10941.127370124761
# 	Predicting var1(t+7)
# 		> expected: 10008.87183333, predicted: 10912.096919603113
# 	Predicting var1(t+8)
# 		> expected: 13015.44604167, predicted: 12551.696388888367
# 	Predicting var1(t+9)
# 		> expected: 14007.74558333, predicted: 11522.387062855109
# 	Predicting var1(t+10)
# 		> expected: 14496.39745833, predicted: 12548.381275077665
# 	Predicting var1(t+11)
# 		> expected: 14619.48133333, predicted: 11498.71295932332
# 	Predicting var1(t+12)
# 		> expected: 15056.54241667, predicted: 11320.949985118525
# 	Predicting var1(t+13)
# 		> expected: 13438.65591667, predicted: 11726.848759374023
# 	Predicting var1(t+14)
# 		> expected: 11939.35920833, predicted: 10453.573021399905
# predicting for cv 9...
# 	Predicting var1(t)
# 		> expected: 14839.69425, predicted: 12833.4861397192
# 	Predicting var1(t+1)
# 		> expected: 15099.88958333, predicted: 13328.35101585863
# 	Predicting var1(t+2)
# 		> expected: 15639.573875, predicted: 13448.782592981657
# 	Predicting var1(t+3)
# 		> expected: 16211.40595833, predicted: 13170.000222078115
# 	Predicting var1(t+4)
# 		> expected: 16082.350375, predicted: 13398.43409210418
# 	Predicting var1(t+5)
# 		> expected: 14285.5935, predicted: 13086.5558380537
# 	Predicting var1(t+6)
# 		> expected: 12979.07733333, predicted: 11519.577803630453
# 	Predicting var1(t+7)
# 		> expected: 16219.35104167, predicted: 13239.806688324254
# 	Predicting var1(t+8)
# 		> expected: 16176.98766667, predicted: 13123.060949298942
# 	Predicting var1(t+9)
# 		> expected: 16214.91404167, predicted: 12666.18191113356
# 	Predicting var1(t+10)
# 		> expected: 14837.46145833, predicted: 12513.87685092558
# 	Predicting var1(t+11)
# 		> expected: 13116.38170833, predicted: 12420.548325190239
# 	Predicting var1(t+12)
# 		> expected: 11266.188625, predicted: 11868.652607266209
# 	Predicting var1(t+13)
# 		> expected: 9918.63116667, predicted: 11576.658725469997
# 	Predicting var1(t+14)
# 		> expected: 13359.83445833, predicted: 12865.285320742489
# predicting for cv 8...
# 	Predicting var1(t)
# 		> expected: 14187.800625, predicted: 14132.242619878394
# 	Predicting var1(t+1)
# 		> expected: 14646.09266667, predicted: 14178.896059723153
# 	Predicting var1(t+2)
# 		> expected: 15239.14554167, predicted: 13836.104293215216
# 	Predicting var1(t+3)
# 		> expected: 14777.66741667, predicted: 13909.129913705752
# 	Predicting var1(t+4)
# 		> expected: 12535.88879167, predicted: 11969.258300284242
# 	Predicting var1(t+5)
# 		> expected: 10282.30733333, predicted: 11770.62086627339
# 	Predicting var1(t+6)
# 		> expected: 12824.1295, predicted: 12919.433147332977
# 	Predicting var1(t+7)
# 		> expected: 13427.25816667, predicted: 14218.288556125599
# 	Predicting var1(t+8)
# 		> expected: 13722.75116667, predicted: 13815.61358729256
# 	Predicting var1(t+9)
# 		> expected: 14135.502375, predicted: 13820.240086069947
# 	Predicting var1(t+10)
# 		> expected: 14563.02679167, predicted: 13765.25753154461
# 	Predicting var1(t+11)
# 		> expected: 12765.36333333, predicted: 12693.233096555823
# 	Predicting var1(t+12)
# 		> expected: 11139.919125, predicted: 12165.861225709332
# 	Predicting var1(t+13)
# 		> expected: 13968.59941667, predicted: 13855.257788124043
# 	Predicting var1(t+14)
# 		> expected: 14459.25758333, predicted: 14497.274404092872
# predicting for cv 7...
# 	Predicting var1(t)
# 		> expected: 14668.13054167, predicted: 14123.631817361193
# 	Predicting var1(t+1)
# 		> expected: 14707.56754167, predicted: 13562.503500865538
# 	Predicting var1(t+2)
# 		> expected: 14043.86975, predicted: 13150.774933136754
# 	Predicting var1(t+3)
# 		> expected: 12176.51279167, predicted: 12107.323695385576
# 	Predicting var1(t+4)
# 		> expected: 11406.84445833, predicted: 10990.60601240813
# 	Predicting var1(t+5)
# 		> expected: 14721.57783333, predicted: 13328.844510061155
# 	Predicting var1(t+6)
# 		> expected: 15088.1805, predicted: 13623.453179069702
# 	Predicting var1(t+7)
# 		> expected: 14903.53866667, predicted: 13782.863516842528
# 	Predicting var1(t+8)
# 		> expected: 15048.16820833, predicted: 12922.664915293368
# 	Predicting var1(t+9)
# 		> expected: 15101.33945833, predicted: 12950.74379255328
# 	Predicting var1(t+10)
# 		> expected: 13219.66816667, predicted: 12528.944755757124
# 	Predicting var1(t+11)
# 		> expected: 11890.95883333, predicted: 11028.277957058706
# 	Predicting var1(t+12)
# 		> expected: 14121.6205, predicted: 13388.364427919449
# 	Predicting var1(t+13)
# 		> expected: 13533.69116667, predicted: 13421.884193480513
# 	Predicting var1(t+14)
# 		> expected: 14360.92133333, predicted: 12959.339600499472
# predicting for cv 6...
# 	Predicting var1(t)
# 		> expected: 14522.45575, predicted: 14385.654757366321
# 	Predicting var1(t+1)
# 		> expected: 14725.69375, predicted: 12964.76499974757
# 	Predicting var1(t+2)
# 		> expected: 13204.44545833, predicted: 11886.700036888442
# 	Predicting var1(t+3)
# 		> expected: 11716.23616667, predicted: 11837.295587965416
# 	Predicting var1(t+4)
# 		> expected: 14608.58329167, predicted: 12371.62511505919
# 	Predicting var1(t+5)
# 		> expected: 14834.67108333, predicted: 12023.929227802628
# 	Predicting var1(t+6)
# 		> expected: 14860.90666667, predicted: 14018.820430914959
# 	Predicting var1(t+7)
# 		> expected: 14877.01941667, predicted: 13745.768379713702
# 	Predicting var1(t+8)
# 		> expected: 13767.50341667, predicted: 12983.474111580728
# 	Predicting var1(t+9)
# 		> expected: 11014.99829167, predicted: 11732.419935466094
# 	Predicting var1(t+10)
# 		> expected: 9496.60404167, predicted: 11022.841046006493
# 	Predicting var1(t+11)
# 		> expected: 12362.05991667, predicted: 13945.022205925105
# 	Predicting var1(t+12)
# 		> expected: 12955.04679167, predicted: 13942.047720197348
# 	Predicting var1(t+13)
# 		> expected: 12945.71195833, predicted: 13569.154825415326
# 	Predicting var1(t+14)
# 		> expected: 13332.61545833, predicted: 13712.614717792794
# predicting for cv 5...
# 	Predicting var1(t)
# 		> expected: 14198.56295833, predicted: 13134.839506237424
# 	Predicting var1(t+1)
# 		> expected: 11296.96458333, predicted: 11680.894867015784
# 	Predicting var1(t+2)
# 		> expected: 9206.60045833, predicted: 10484.520895794289
# 	Predicting var1(t+3)
# 		> expected: 11830.310375, predicted: 12668.839739578538
# 	Predicting var1(t+4)
# 		> expected: 12475.77254167, predicted: 13051.278922158826
# 	Predicting var1(t+5)
# 		> expected: 12928.44620833, predicted: 13865.167085452034
# 	Predicting var1(t+6)
# 		> expected: 12481.91258333, predicted: 13560.348666654121
# 	Predicting var1(t+7)
# 		> expected: 11564.9615, predicted: 13333.955521254924
# 	Predicting var1(t+8)
# 		> expected: 9796.23133333, predicted: 11546.261407335476
# 	Predicting var1(t+9)
# 		> expected: 8644.74808333, predicted: 11193.48580781222
# 	Predicting var1(t+10)
# 		> expected: 12049.438875, predicted: 13015.342994374638
# 	Predicting var1(t+11)
# 		> expected: 12864.37379167, predicted: 13792.756640076495
# 	Predicting var1(t+12)
# 		> expected: 12801.83, predicted: 13507.803289277872
# 	Predicting var1(t+13)
# 		> expected: 11890.73770833, predicted: 13465.626932061827
# 	Predicting var1(t+14)
# 		> expected: 11762.59358333, predicted: 12871.488752663063
# predicting for cv 4...
# 	Predicting var1(t)
# 		> expected: 10305.34875, predicted: 10162.793426350221
# 	Predicting var1(t+1)
# 		> expected: 9318.59433333, predicted: 8256.328171833375
# 	Predicting var1(t+2)
# 		> expected: 12069.142875, predicted: 11840.159807761253
# 	Predicting var1(t+3)
# 		> expected: 11989.101125, predicted: 12459.257605997973
# 	Predicting var1(t+4)
# 		> expected: 12151.25758333, predicted: 12225.574755639345
# 	Predicting var1(t+5)
# 		> expected: 12512.48358333, predicted: 12390.354196539736
# 	Predicting var1(t+6)
# 		> expected: 12271.66291667, predicted: 12219.697453186525
# 	Predicting var1(t+7)
# 		> expected: 10395.1, predicted: 10768.435410668426
# 	Predicting var1(t+8)
# 		> expected: 9137.30708333, predicted: 9607.677459294824
# 	Predicting var1(t+9)
# 		> expected: 11983.96583333, predicted: 11776.70100384536
# 	Predicting var1(t+10)
# 		> expected: 12160.46825, predicted: 12111.664045452657
# 	Predicting var1(t+11)
# 		> expected: 12080.641, predicted: 12543.641300150393
# 	Predicting var1(t+12)
# 		> expected: 11381.11270833, predicted: 12201.308864325567
# 	Predicting var1(t+13)
# 		> expected: 8310.66466667, predicted: 11662.164779245319
# 	Predicting var1(t+14)
# 		> expected: 8604.08054167, predicted: 10644.259454538687
# predicting for cv 3...
# 	Predicting var1(t)
# 		> expected: 8044.32816667, predicted: 8133.501436709181
# 	Predicting var1(t+1)
# 		> expected: 11133.275, predicted: 11714.54535786907
# 	Predicting var1(t+2)
# 		> expected: 11832.275, predicted: 11690.23725303488
# 	Predicting var1(t+3)
# 		> expected: 11905.54341667, predicted: 11792.850469749803
# 	Predicting var1(t+4)
# 		> expected: 11325.16608333, predicted: 11933.905939835897
# 	Predicting var1(t+5)
# 		> expected: 11635.15216667, predicted: 10747.171296455297
# 	Predicting var1(t+6)
# 		> expected: 9745.995625, predicted: 9725.994825868967
# 	Predicting var1(t+7)
# 		> expected: 8676.43583333, predicted: 8861.09319049515
# 	Predicting var1(t+8)
# 		> expected: 11917.18516667, predicted: 11496.873906903926
# 	Predicting var1(t+9)
# 		> expected: 12640.41333333, predicted: 11760.071752204978
# 	Predicting var1(t+10)
# 		> expected: 13018.60175, predicted: 12014.185167453346
# 	Predicting var1(t+11)
# 		> expected: 13048.24545833, predicted: 10852.032164286913
# 	Predicting var1(t+12)
# 		> expected: 12261.400625, predicted: 11227.969242179808
# 	Predicting var1(t+13)
# 		> expected: 10444.07595833, predicted: 9360.088700139599
# 	Predicting var1(t+14)
# 		> expected: 8794.163125, predicted: 8726.778189195727
# predicting for cv 2...
# 	Predicting var1(t)
# 		> expected: 11643.82154167, predicted: 11580.047788161884
# 	Predicting var1(t+1)
# 		> expected: 11941.66258333, predicted: 12039.216850445126
# 	Predicting var1(t+2)
# 		> expected: 11643.86191667, predicted: 11819.70282378801
# 	Predicting var1(t+3)
# 		> expected: 11442.40841667, predicted: 11502.774315551578
# 	Predicting var1(t+4)
# 		> expected: 11156.521, predicted: 11507.489961693354
# 	Predicting var1(t+5)
# 		> expected: 9333.92008333, predicted: 10132.304703209857
# 	Predicting var1(t+6)
# 		> expected: 7742.3945, predicted: 8358.272658625561
# 	Predicting var1(t+7)
# 		> expected: 10808.54866667, predicted: 11694.910501707942
# 	Predicting var1(t+8)
# 		> expected: 11654.62308112, predicted: 12024.975196134814
# 	Predicting var1(t+9)
# 		> expected: 11608.52466322, predicted: 11475.656034209704
# 	Predicting var1(t+10)
# 		> expected: 11361.00188129, predicted: 11496.177269712358
# 	Predicting var1(t+11)
# 		> expected: 11305.70706206, predicted: 11468.205730686097
# 	Predicting var1(t+12)
# 		> expected: 10060.54978729, predicted: 10062.659978078922
# 	Predicting var1(t+13)
# 		> expected: 8994.85674774, predicted: 8512.92017588777
# 	Predicting var1(t+14)
# 		> expected: 11424.08754167, predicted: 11576.366788507894
# predicting for cv 1...
# 	Predicting var1(t)
# 		> expected: 11964.909375, predicted: 11742.29490159845
# 	Predicting var1(t+1)
# 		> expected: 12269.051375, predicted: 11752.398105879569
# 	Predicting var1(t+2)
# 		> expected: 12021.41545833, predicted: 11673.18263280014
# 	Predicting var1(t+3)
# 		> expected: 11802.52645833, predicted: 11756.246350118126
# 	Predicting var1(t+4)
# 		> expected: 10256.970375, predicted: 10086.618251221176
# 	Predicting var1(t+5)
# 		> expected: 8938.579125, predicted: 9414.412437259482
# 	Predicting var1(t+6)
# 		> expected: 11713.10433333, predicted: 11647.149970102593
# 	Predicting var1(t+7)
# 		> expected: 12054.19504167, predicted: 11914.721892459947
# 	Predicting var1(t+8)
# 		> expected: 12186.721375, predicted: 11408.0590723506
# 	Predicting var1(t+9)
# 		> expected: 12482.52370833, predicted: 11993.182060853731
# 	Predicting var1(t+10)
# 		> expected: 12520.80383333, predicted: 11603.84333900538
# 	Predicting var1(t+11)
# 		> expected: 10525.490875, predicted: 10317.489987196555
# 	Predicting var1(t+12)
# 		> expected: 9074.21125, predicted: 9163.67476409575
# 	Predicting var1(t+13)
# 		> expected: 11648.70958333, predicted: 11211.218489322331
# 	Predicting var1(t+14)
# 		> expected: 12162.75679167, predicted: 11729.157162021822

# %%
mapes = []
for x in d:
    meas = get_measures(pd.Series(d[x]["pred"]),pd.Series(d[x]["test"]))
    print(meas)
    mapes.append(meas["mape"])
# Out:
# {'erro': 6929812.02285, 'mae': 595.668535, 'mse': 461987.46819, 'rmse': 679.6966, 'mape': 0.051835, 'smape': 5.343942}
# {'erro': 23738434.432935, 'mae': 1161.12327, 'mse': 1582562.295529, 'rmse': 1257.999323, 'mape': 0.09065, 'smape': 9.464768}
# {'erro': 19532722.99147, 'mae': 973.587256, 'mse': 1302181.532765, 'rmse': 1141.131689, 'mape': 0.075065, 'smape': 7.879668}
# {'erro': 21714137.570674, 'mae': 943.130296, 'mse': 1447609.171378, 'rmse': 1203.166311, 'mape': 0.068326, 'smape': 7.207979}
# {'erro': 32817865.376232, 'mae': 1108.775918, 'mse': 2187857.691749, 'rmse': 1479.140863, 'mape': 0.103243, 'smape': 9.426864}
# {'erro': 49165584.590927, 'mae': 1525.617932, 'mse': 3277705.639395, 'rmse': 1810.443492, 'mape': 0.112255, 'smape': 12.085967}
# {'erro': 72021651.270165, 'mae': 1980.603936, 'mse': 4801443.418011, 'rmse': 2191.219619, 'mape': 0.133475, 'smape': 14.273886}
# {'erro': 7931701.749618, 'mae': 546.062412, 'mse': 528780.116641, 'rmse': 727.172687, 'mape': 0.042352, 'smape': 4.195732}
# {'erro': 20803095.182333, 'mae': 1008.157929, 'mse': 1386873.012156, 'rmse': 1177.655727, 'mape': 0.070257, 'smape': 7.368625}
# {'erro': 27235598.801109, 'mae': 1130.577679, 'mse': 1815706.586741, 'rmse': 1347.481572, 'mape': 0.085208, 'smape': 8.691786}
# {'erro': 24677997.591616, 'mae': 1167.10489, 'mse': 1645199.839441, 'rmse': 1282.653437, 'mape': 0.105613, 'smape': 9.900118}
# {'erro': 18133293.011204, 'mae': 661.801557, 'mse': 1208886.200747, 'rmse': 1099.493611, 'mape': 0.071041, 'smape': 6.49513}
# {'erro': 10603692.020423, 'mae': 620.842633, 'mse': 706912.801362, 'rmse': 840.781066, 'mape': 0.052286, 'smape': 5.436939}
# {'erro': 2428637.661072, 'mae': 299.089947, 'mse': 161909.177405, 'rmse': 402.379395, 'mape': 0.029946, 'smape': 2.930346}
# {'erro': 2836397.641487, 'mae': 355.927546, 'mse': 189093.176099, 'rmse': 434.848452, 'mape': 0.030654, 'smape': 3.115692}

# %%
np.mean(mapes)
# Out:
# 0.07481373333333334

# %%
with open('multivariate_lightgbm_cv.json', 'w') as f:
    json.dump(d, f)
