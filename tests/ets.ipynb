# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import rcParams
from sktime.forecasting.ets import AutoETS
from load import load_data
from load import train_test_split
from load import get_measures


import warnings # retirar avisos
warnings.filterwarnings('ignore')
rcParams['figure.figsize'] = 15, 5

# %%
df = load_data()
df["load_mwmed"].interpolate(method = "linear", inplace = True)

# %%
n_test = 31
train, test = train_test_split(df, n_test)
train
# Out:
#               load_mwmed
# date
# 2000-01-01   4800.650000
# 2000-01-02   4899.800000
# 2000-01-03   6261.554167
# 2000-01-04   6733.741667
# 2000-01-05   6961.170833
# ...                  ...
# 2022-04-26  12640.413333
# 2022-04-27  13018.601750
# 2022-04-28  13048.245458
# 2022-04-29  12261.400625
# 2022-04-30  10444.075958
#
# [8157 rows x 1 columns]

# %%
forecaster = AutoETS(auto=True, n_jobs=-1, seasonal = "add", sp=7 )
forecaster.fit(train.load_mwmed.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\user\Projetos\projecao_demanda_eletrica\tests\ets.ipynb Cell 4' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Projetos/projecao_demanda_eletrica/tests/ets.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> forecaster = AutoETS(auto=True, n_jobs=-1, seasonal = "add", sp=(7, 365.25) )
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Projetos/projecao_demanda_eletrica/tests/ets.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> forecaster.fit(train.load_mwmed.values)
#
# File c:\Users\user\anaconda3\lib\site-packages\sktime\forecasting\base\_base.py:263, in BaseForecaster.fit(self, y, X, fh)
#     <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=260'>261</a> # we call the ordinary _fit if no looping/vectorization needed
#     <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=261'>262</a> if not vectorization_needed:
# --> <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=262'>263</a>     self._fit(y=y_inner, X=X_inner, fh=fh)
#     <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=263'>264</a> else:
#     <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=264'>265</a>     # otherwise we call the vectorized version of fit
#     <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=265'>266</a>     self._vectorize("fit", y=y_inner, X=X_inner, fh=fh)
#
# File c:\Users\user\anaconda3\lib\site-packages\sktime\forecasting\base\adapters\_statsmodels.py:53, in _StatsModelsAdapter._fit(self, y, X, fh)
#      <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/base/adapters/_statsmodels.py?line=50'>51</a> if isinstance(y, pd.Series) and y.index.is_integer():
#      <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/base/adapters/_statsmodels.py?line=51'>52</a>     y, X = _coerce_int_to_range_index(y, X)
# ---> <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/base/adapters/_statsmodels.py?line=52'>53</a> self._fit_forecaster(y, X)
#      <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/base/adapters/_statsmodels.py?line=53'>54</a> return self
#
# File c:\Users\user\anaconda3\lib\site-packages\sktime\forecasting\ets.py:259, in AutoETS._fit_forecaster(self, y, X)
#     <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/ets.py?line=255'>256</a> else:
#     <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/ets.py?line=256'>257</a>     trend_range = ["add", None]
# --> <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/ets.py?line=258'>259</a> if self.sp <= 1 or self.sp is None:
#     <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/ets.py?line=259'>260</a>     seasonal_range = [None]
#     <a href='file:///c%3A/Users/user/anaconda3/lib/site-packages/sktime/forecasting/ets.py?line=260'>261</a> elif (y > 0).all():
#
# TypeError: '<=' not supported between instances of 'tuple' and 'int'

# %%
y_pred = forecaster.predict(fh=[x for x in range(0, 31)])
y_pred = [x for x in y_pred.flatten()]
plt.plot(y_pred, label = "forecast")
plt.plot(test.load_mwmed.reset_index(drop = True), label = "test")
plt.legend()
plt.show()

# %%
medidas_fc = get_measures(pd.Series(y_pred), test.load_mwmed) 
df_medidas_fc = pd.DataFrame([medidas_fc])
df_medidas_fc
# Out:
#           erro      mae         mse     rmse  mape  smape
# 0  67688958.59  1270.26  2183514.79  1477.67  0.12  11.77
